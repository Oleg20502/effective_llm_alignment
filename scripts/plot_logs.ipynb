# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
logging_dir = "/home/kashurin/.local/models/sft-grag-tlite-1.0-unsloth-lora-16-qkvo/logs/"

train_df = pd.read_csv(f"{logging_dir}train_logs.csv")
eval_df = pd.read_csv(f"{logging_dir}eval_logs.csv")

# %%
",".join(str(i) for i in range(4))
# Out:
# '0,1,2,3'

# %%
eval_df
# Out:
#    eval_loss  eval_runtime  eval_samples_per_second  eval_steps_per_second  \
# 0   1.333949      126.8593                    1.577                  1.577
# 1   0.758304      127.0390                    1.574                  1.574
# 2   0.467715      126.9846                    1.575                  1.575
# 3   0.392839      126.9665                    1.575                  1.575
# 4   0.363760      127.1159                    1.573                  1.573
# 5   0.357714      126.9254                    1.576                  1.576
#
#       epoch
# 0  0.001600
# 1  0.003199
# 2  0.004799
# 3  0.006399
# 4  0.007998
# 5  0.009598

# %%
plt.figure(figsize=(8, 6), dpi=100)
plt.plot(train_df['Step'], train_df['Loss'], color='blue', label='Train')
plt.plot(range(10, 70, 10), eval_df['eval_loss'], color='red', label='Val')
plt.legend(fontsize=12)
plt.title('T-lite, r=16, qkvogud', fontsize=14)
plt.xlabel('Step', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.tight_layout()
plt.show()
